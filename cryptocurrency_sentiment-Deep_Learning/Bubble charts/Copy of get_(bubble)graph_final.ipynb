# %%
# !pip install plotly
# !pip install pymysql
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (4.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly) (1.3.3)
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 930 kB/s
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2

# %%
import pandas as pd
import numpy as np
import pymysql

from datetime import datetime, timedelta
import plotly.express as px

# %%
def get_db():
    db = pymysql.connect(, charset='utf8')
    cursor = db.cursor(pymysql.cursors.DictCursor)
    sql = 'SELECT * FROM coin'
    cursor.execute(sql)
    result = cursor.fetchall()
    test = pd.DataFrame(result)
    return test

# %%
def pre_data():
    test = get_db()
    test['date'] = pd.to_datetime(test['date'])
    test['week'] = test['date'].dt.weekday

    indexNames = test[(test['week'] == 5) | (test['week'] == 6)].index
    test.drop(indexNames, inplace=True)
    
    test['s'] = - test['s']
    test['s'] = test['s'] + 1
    test['s'] = round(test['s'], 3)

    test['num_1'] = test.groupby('coin')['num'].diff()
    test['num_3'] = test.groupby('coin')['num'].diff(3)
    test['num_5'] = test.groupby('coin')['num'].diff(5)
    test['s_1'] = test.groupby('coin')['s'].diff()
    test['s_3'] = test.groupby('coin')['s'].diff(3)
    test['s_5'] = test.groupby('coin')['s'].diff(5)

    test.rename(columns = {'num':'게시물 수', 's':'감정분석 평균'}, inplace=True)

    week = datetime.now() - timedelta(days=7)
    week = week.strftime('%Y-%m-%d')

    data = test.loc[test.date == week]
    data.reset_index(drop=True, inplace=True)
    return data

# %%
def get_plot_1d():
    data = pre_data()
    hovertemplate = []
    for num in range(len(data)):
        num_1 = data.iloc[num, 7]
        s_1 = round(data.iloc[num, 10], 3)
        num_ = data.iloc[num, 3]
        s = round(data.iloc[num, 4], 3)
        hovertemplate.append(f"게시물 수 비교 : {num_1}<br>감정분석 비교 : {s_1}<br>하루동안의 게시물 수 : {num}<br>하루동안의 감정분석 : {s}")
    fig = px.scatter(data, x='num_1', y='s_1',
                 color='감정분석 평균', size=data['게시물 수'], range_color=(-1,1),
                 size_max=50, hover_data = None,
                 template='seaborn',
                 labels={'num_1':'감소                                    <게시물 수>                                    증가',
                         's_1':'부정                           <감정분석>                           긍정'})
    fig.update_layout(
        xaxis=dict(
            showline=True,
            zeroline=True,
            showgrid=False,
            showticklabels=True,          
        ),
        yaxis=dict(
            showgrid=False,
            zeroline=True,
            showline=False,
            showticklabels=True,
        ),
        showlegend=False
    )
    fig.update_coloraxes(colorscale=px.colors.diverging.Portland,
                         colorbar_nticks=3,
                         colorbar_tickcolor='white',
                         colorbar_title='')
    for i in range(data.shape[0]):
        fig.add_annotation(x=data.num_1[i], y=data.s_1[i], text=data.coin[i],
                 showarrow=False)
    fig.update_traces(hovertemplate=hovertemplate)
    return fig

# %%
get_plot_1d()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="baa6f7a3-f625-4998-b80e-ae21341ef732" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("baa6f7a3-f625-4998-b80e-ae21341ef732")) {
#                     Plotly.newPlot(
#                         'baa6f7a3-f625-4998-b80e-ae21341ef732',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": ["\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 0<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.445", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 1<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.388", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 2<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.423", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 3<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.43", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 4<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.37", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 5<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.448", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 6<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.333", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 7<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.261", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 8<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.432", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 0.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : 0.074<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 9<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.222", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : -24.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.114<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 10<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.161", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : -7.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.173<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 11<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.111", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : -2.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : 0.026<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 12<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.276", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : -20.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.378<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 13<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.074", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : -1.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : 0.083<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 14<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.333", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 2.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.25<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 15<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.0", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : -78.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.134<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 16<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.14"], "legendgroup": "", "marker": {"color": ...
#                         {"annotations": [{"showarrow": false, "text": "ADA", "x": null, "y": null}, {"showarrow": false, "text": "BCH", "x": null, "y": null}, {"showarrow": false, "text": "BTC", "x": null, "y": null}, {"showarrow": false, "text": "DOGE", "x": null, "y": null}, {"showarrow": false, "text": "EOS", "x": null, "y": null}, {"showarrow": false, "text": "ETH", "x": null, "y": null}, {"showarrow": false, "text": "OMG", "x": null, "y": null}, {"showarrow": false, "text": "SNT", "x": null, "y": null}, {"showarrow": false, "text": "XRP", "x": null, "y": null}, {"showarrow": false, "text": "ada", "x": 0.0, "y": 0.07400000000000001}, {"showarrow": false, "text": "bch", "x": -24.0, "y": -0.11400000000000002}, {"showarrow": false, "text": "btc", "x": -7.0, "y": -0.173}, {"showarrow": false, "text": "doge", "x": -2.0, "y": 0.026000000000000023}, {"showarrow": false, "text": "eos", "x": -20.0, "y": -0.378}, {"showarrow": false, "text": "omg", "x": -1.0, "y": 0.08300000000000002}, {"showarrow": false, "text": "snt", "x": 2.0, "y": -0.25}, {"showarrow": false, "text": "xrp", "x": -78.0, "y": -0.134}], "coloraxis": {"cmax": 1, "cmin": -1, "colorbar": {"nticks": 3, "tickcolor": "white", "title": {"text": ""}}, "colorscale": [[0.0, "rgb(12,51,131)"], [0.25, "rgb(10,136,186)"], [0.5, "rgb(242,211,56)"], [0.75, "rgb(242,143,56)"], [1.0, "rgb(217,30,30)"]]}, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "margin": {"t": 60}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(36,36,36)"}, "error_y": {"color": "rgb(36,36,36)"}, "marker": {"line": {"color": "rgb(234,234,242)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(234,234,242)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "baxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2},

# %%
def get_plot_3d():
    data = pre_data()
    hovertemplate = []
    for num in range(len(data)):
        name = data.iloc[num, 2]
        num_3 = data.iloc[num, 8]
        s_3 = round(data.iloc[num, 11], 3)
        num_ = data.iloc[num, 3]
        s = round(data.iloc[num, 4], 3)
        hovertemplate.append(f"게시물 수 비교 : {num_3}<br>감정분석 비교 : {s_3}<br>하루동안의 게시물 수 : {num}<br>하루동안의 감정분석 : {s}")
    fig = px.scatter(data, x='num_3', y='s_3',
                 color='감정분석 평균', size=data['게시물 수'], range_color=(-1,1),
                 size_max=50, hover_data = None,
                 template='seaborn',
                 labels={'num_3':'감소                                    <게시물 수>                                    증가',
                         's_3':'부정                           <감정분석>                           긍정'})
    fig.update_layout(
        xaxis=dict(
            showline=True,
            showgrid=False,
            showticklabels=True,          
        ),
        yaxis=dict(
            showgrid=False,
            zeroline=True,
            showline=False,
            showticklabels=True,
        ),
        showlegend=False
    )
    fig.update_coloraxes(colorscale=px.colors.diverging.Portland,
                        #  colorbar_showticklabels=False,
                         colorbar_nticks=3,
                         colorbar_tickcolor='white',
                         colorbar_title='')
    for i in range(data.shape[0]):
        fig.add_annotation(x=data.num_3[i], y=data.s_3[i], text=data.coin[i],
                 showarrow=False)
    fig.update_traces(hovertemplate=hovertemplate)
    return fig

# %%
get_plot_3d()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9c96d5bf-6223-435b-abbe-8031249cbf65" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c96d5bf-6223-435b-abbe-8031249cbf65")) {
#                     Plotly.newPlot(
#                         '9c96d5bf-6223-435b-abbe-8031249cbf65',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": ["\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 0<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.445", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 1<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.388", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 2<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.423", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 3<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.43", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 4<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.37", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 5<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.448", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 6<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.333", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 7<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.261", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 8<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.432", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 25.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.778<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 9<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.222", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 20.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.839<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 10<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.161", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 5.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -1.111<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 11<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.111", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 40.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.224<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 12<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.276", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 72.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.596<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 13<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.074", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : -1.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.667<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 14<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.333", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 3.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -1.0<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 15<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.0", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 24.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : 0.201<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 16<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.14"], "legendgroup": "", "marker": {"color": [ ...
#                         {"annotations": [{"showarrow": false, "text": "ADA", "x": null, "y": null}, {"showarrow": false, "text": "BCH", "x": null, "y": null}, {"showarrow": false, "text": "BTC", "x": null, "y": null}, {"showarrow": false, "text": "DOGE", "x": null, "y": null}, {"showarrow": false, "text": "EOS", "x": null, "y": null}, {"showarrow": false, "text": "ETH", "x": null, "y": null}, {"showarrow": false, "text": "OMG", "x": null, "y": null}, {"showarrow": false, "text": "SNT", "x": null, "y": null}, {"showarrow": false, "text": "XRP", "x": null, "y": null}, {"showarrow": false, "text": "ada", "x": 25.0, "y": -0.778}, {"showarrow": false, "text": "bch", "x": 20.0, "y": -0.839}, {"showarrow": false, "text": "btc", "x": 5.0, "y": -1.111}, {"showarrow": false, "text": "doge", "x": 40.0, "y": -0.22399999999999998}, {"showarrow": false, "text": "eos", "x": 72.0, "y": -0.596}, {"showarrow": false, "text": "omg", "x": -1.0, "y": -0.667}, {"showarrow": false, "text": "snt", "x": 3.0, "y": -1.0}, {"showarrow": false, "text": "xrp", "x": 24.0, "y": 0.201}], "coloraxis": {"cmax": 1, "cmin": -1, "colorbar": {"nticks": 3, "tickcolor": "white", "title": {"text": ""}}, "colorscale": [[0.0, "rgb(12,51,131)"], [0.25, "rgb(10,136,186)"], [0.5, "rgb(242,211,56)"], [0.75, "rgb(242,143,56)"], [1.0, "rgb(217,30,30)"]]}, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "margin": {"t": 60}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(36,36,36)"}, "error_y": {"color": "rgb(36,36,36)"}, "marker": {"line": {"color": "rgb(234,234,242)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(234,234,242)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "baxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "rgb(2,4,25)"], [0.06274509803921569, "rgb(24,15,41)"], [0.125490196078

# %%
def get_plot_5d():
    data = pre_data()
    hovertemplate = []
    for num in range(len(data)):
        num_5 = data.iloc[num, 9]
        s_5 = round(data.iloc[num, 12], 3)
        num_ = data.iloc[num, 3]
        s = round(data.iloc[num, 4], 3)
        hovertemplate.append(f"게시물 수 비교 : {num_5}<br>감정분석 비교 : {s_5}<br>하루동안의 게시물 수 : {num}<br>하루동안의 감정분석 : {s}")
    fig = px.scatter(data, x='num_5', y='s_5',
                 color='감정분석 평균', size=data['게시물 수'], range_color=(-1,1),
                 size_max=50, hover_data = None,
                 template='seaborn',
                 labels={'num_5':'감소                                    <게시물 수>                                    증가',
                         's_5':'부정                           <감정분석>                           긍정'})
    fig.update_layout(
        xaxis=dict(
            showline=True,
            showgrid=False,
            showticklabels=True,          
        ),
        yaxis=dict(
            showgrid=False,
            zeroline=True,
            showline=False,
            showticklabels=True,
        ),
        showlegend=False
    )
    fig.update_coloraxes(colorscale=px.colors.diverging.Portland,
                        #  colorbar_showticklabels=False,
                         colorbar_nticks=3,
                         colorbar_tickcolor='white',
                         colorbar_title='')
    for i in range(data.shape[0]):
        fig.add_annotation(x=data.num_5[i], y=data.s_5[i], text=data.coin[i],
                 showarrow=False)
    fig.update_traces(hovertemplate=hovertemplate)
    return fig

# %%
get_plot_5d()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="444e678a-47f5-4560-8829-ec11b64d6e5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("444e678a-47f5-4560-8829-ec11b64d6e5b")) {
#                     Plotly.newPlot(
#                         '444e678a-47f5-4560-8829-ec11b64d6e5b',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": ["\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 0<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.445", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 1<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.388", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 2<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.423", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 3<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.43", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 4<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.37", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 5<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.448", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 6<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.333", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 7<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.261", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : nan<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : nan<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 8<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.432", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 21.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.445<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 9<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.222", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 46.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.539<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 10<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.161", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 7.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.111<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 11<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.111", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 51.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.295<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 12<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.276", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 76.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.548<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 13<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : -0.074", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : -1.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : -0.167<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 14<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.333", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 3.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : 0.333<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 15<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.0", "\uac8c\uc2dc\ubb3c \uc218 \ube44\uad50 : 29.0<br>\uac10\uc815\ubd84\uc11d \ube44\uad50 : 0.14<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac8c\uc2dc\ubb3c \uc218 : 16<br>\ud558\ub8e8\ub3d9\uc548\uc758 \uac10\uc815\ubd84\uc11d : 0.14"], "legendgroup": "", "marker": {"color": [ ...
#                         {"annotations": [{"showarrow": false, "text": "ADA", "x": null, "y": null}, {"showarrow": false, "text": "BCH", "x": null, "y": null}, {"showarrow": false, "text": "BTC", "x": null, "y": null}, {"showarrow": false, "text": "DOGE", "x": null, "y": null}, {"showarrow": false, "text": "EOS", "x": null, "y": null}, {"showarrow": false, "text": "ETH", "x": null, "y": null}, {"showarrow": false, "text": "OMG", "x": null, "y": null}, {"showarrow": false, "text": "SNT", "x": null, "y": null}, {"showarrow": false, "text": "XRP", "x": null, "y": null}, {"showarrow": false, "text": "ada", "x": 21.0, "y": -0.44500000000000006}, {"showarrow": false, "text": "bch", "x": 46.0, "y": -0.5389999999999999}, {"showarrow": false, "text": "btc", "x": 7.0, "y": -0.111}, {"showarrow": false, "text": "doge", "x": 51.0, "y": -0.29499999999999993}, {"showarrow": false, "text": "eos", "x": 76.0, "y": -0.5479999999999999}, {"showarrow": false, "text": "omg", "x": -1.0, "y": -0.16699999999999998}, {"showarrow": false, "text": "snt", "x": 3.0, "y": 0.333}, {"showarrow": false, "text": "xrp", "x": 29.0, "y": 0.14}], "coloraxis": {"cmax": 1, "cmin": -1, "colorbar": {"nticks": 3, "tickcolor": "white", "title": {"text": ""}}, "colorscale": [[0.0, "rgb(12,51,131)"], [0.25, "rgb(10,136,186)"], [0.5, "rgb(242,211,56)"], [0.75, "rgb(242,143,56)"], [1.0, "rgb(217,30,30)"]]}, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "margin": {"t": 60}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(36,36,36)"}, "error_y": {"color": "rgb(36,36,36)"}, "marker": {"line": {"color": "rgb(234,234,242)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(234,234,242)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "baxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "

# %%
get_plot_5d().write_html('full_html=True.html')

# %%
get_plot_5d().write_html('full_html=False.html', full_html=False)
