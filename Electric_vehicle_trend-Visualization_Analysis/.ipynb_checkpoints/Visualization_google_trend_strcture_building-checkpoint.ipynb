# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools

plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['font.family'] = 'Malgun Gothic'

# %% [markdown]
# ## 데이터 가지고 오기 & index 나라이름으로 하기

# %%
# 1년 대한민국 랭킹 18위
DF1 = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%201-y.xlsx')

DF1.set_index('Country Name', inplace = True)


DF1['Search ratio'].sort_values().plot(kind = 'barh', grid = True, figsize = (7,20), color ='dodgerblue', width = 0.5)
plt.show()

# %%
# 5년 대한민국 랭킹 23위
DF2 = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%205-y.xlsx')

DF2.set_index('Country Name', inplace = True)

DF2['Search ratio'].sort_values().plot(kind = 'barh', grid = True, figsize = (7,20))
plt.show()

# %% [markdown]
# ## 2. 우리나라 다른색 마크해보기

# %% [markdown]
# 일단 각나라에 '색' 열을 추가해준다. 대한민국만 다르게\
# 그리고\
# 전부 가각 리스트로 불러온다

# %% [markdown]
# ### 색 인덱스 파일에 추가하기

# %%
df = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%205-y.xlsx', usecols = [0,1,2])
df['colorIndex'] = np.where(df['Country Name']=='대한민국', 'red', 'dodgerblue')
df.to_excel('c://My_data//electric_vehicle_serach_ranktoday%205-y.xlsx', index = False)

# %% [markdown]
# ## 여기서 부터 다시

# %% [markdown]
# 데이터 프레임으로 꺼네 각 행을 역순으로 리스트에 저장
# 3개의 리스트를 가각 변수, 색, y값으로 지정한다.

# %%
# 5년 대한민국 랭킹 23위
DF2_countryN = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%205-y.xlsx', usecols = [1])
DF2_searchR = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%205-y.xlsx', usecols = [2])
DF2_color = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%205-y.xlsx', usecols = [3])

# %%
DF2 = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%205-y.xlsx', usecols = [1,2,3])
DF2.head(3)
# Out:
#   Country Name  Search ratio  colorIndex
# 0         뉴질랜드           100  dodgerblue
# 1          캐나다            79  dodgerblue
# 2           네팔            77  dodgerblue

# %%
color_ls=list(reversed((np.array(DF2['colorIndex'].tolist()))))

countryN_ls=list(reversed(np.array(DF2['Country Name'].tolist())))

searchR_ls=list(reversed(np.array(DF2['Search ratio'].tolist())))

# %%
plt.figure(figsize=(7,20))
y = np.arange(len(countryN_ls))
plt.barh(y, searchR_ls, color=color_ls)
plt.yticks(y, countryN_ls)

D5 = plt.xlabel('Searching Ratio', labelpad=20, )
D5 = plt.ylabel('Country Name', labelpad=20, )


plt.show(D5)

# %% [markdown]
# ## 1년 검색데이터 한번에 시행해보기

# %%
df = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%201-y.xlsx', usecols = [0,1,2])
df['colorIndex'] = np.where(df['Country Name']=='대한민국', 'red', 'dodgerblue')
df.to_excel('c://My_data//electric_vehicle_serach_ranktoday%201-y.xlsx', index = False)

DF1 = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%201-y.xlsx', usecols = [1,2,3])

color_ls=list(reversed((np.array(DF1['colorIndex'].tolist()))))

countryN_ls=list(reversed(np.array(DF1['Country Name'].tolist())))

searchR_ls=list(reversed(np.array(DF1['Search ratio'].tolist())))

plt.figure(figsize=(7,20))
y = np.arange(len(countryN_ls))
plt.barh(y, searchR_ls, color=color_ls)
plt.yticks(y, countryN_ls)

D1 = plt.xlabel('Searching Ratio', labelpad=20, )
D1 = plt.ylabel('Country Name', labelpad=20, )


plt.show()

# %% [markdown]
# ## 한자리에 그리기

# %%
df = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%201-y.xlsx', usecols = [0,1,2])
df['colorIndex'] = np.where(df['Country Name']=='대한민국', 'red', 'dodgerblue')
df.to_excel('c://My_data//electric_vehicle_serach_ranktoday%201-y.xlsx', index = False)

DF1 = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%201-y.xlsx', usecols = [1,2,3])

color_ls=list(reversed((np.array(DF1['colorIndex'].tolist()))))
countryN_ls=list(reversed(np.array(DF1['Country Name'].tolist())))
searchR_ls=list(reversed(np.array(DF1['Search ratio'].tolist())))

plt.figure(figsize=(7,20))

plt.subplot(1,2,1)

y = np.arange(len(countryN_ls))
plt.barh(y, searchR_ls, color=color_ls)
plt.yticks(y, countryN_ls)

D1=plt.xlabel('Searching Ratio', labelpad=20, )
D1=plt.ylabel('Country Name', labelpad=20, )




df = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%205-y.xlsx', usecols = [0,1,2])
df['colorIndex'] = np.where(df['Country Name']=='대한민국', 'red', 'dodgerblue')
df.to_excel('c://My_data//electric_vehicle_serach_ranktoday%205-y.xlsx', index = False)

DF5 = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%205-y.xlsx', usecols = [1,2,3])

color_ls=list(reversed((np.array(DF5['colorIndex'].tolist()))))
countryN_ls=list(reversed(np.array(DF5['Country Name'].tolist())))
searchR_ls=list(reversed(np.array(DF5['Search ratio'].tolist())))

plt.subplot(1,2,2)

y = np.arange(len(countryN_ls))
plt.barh(y, searchR_ls, color=color_ls)
plt.yticks(y, countryN_ls)

D5=plt.xlabel('Searching Ratio', labelpad=20, )
D5=plt.ylabel('Country Name', labelpad=20, )
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-35-7c457b4963ab> in <module>
#       1 df = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%201-y.xlsx', usecols = [0,1,2])
#       2 df['colorIndex'] = np.where(df['Country Name']=='대한민국', 'red', 'dodgerblue')
# ----> 3 df.to_excel('c://My_data//electric_vehicle_serach_ranktoday%201-y.xlsx', index = False)
#       4
#       5 DF1 = pd.read_excel('c://My_data//electric_vehicle_serach_ranktoday%201-y.xlsx', usecols = [1,2,3])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2187             inf_rep=inf_rep,
#    2188         )
# -> 2189         formatter.write(
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(1, 2, 1)                # nrows=2, ncols=1, index=1
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.ylabel('Damped oscillation')

plt.subplot(1, 2, 2)                # nrows=2, ncols=1, index=2
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
