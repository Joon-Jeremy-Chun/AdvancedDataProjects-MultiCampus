# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
import warnings

from pprint import pprint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -l '/content/drive/MyDrive/Colab Notebooks/datasets/test/want.csv'
# Out:
# -rw------- 1 root root 215311 Nov 10 07:39 '/content/drive/MyDrive/Colab Notebooks/datasets/test/want.csv'

# %%
DF = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datasets/test/want.csv')

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1239 entries, 0 to 1238
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  1239 non-null   object
#  1   text        1239 non-null   object
#  2   s           1239 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 29.2+ KB

# %%
DF.head(20)
# Out:
#                         created_at  ...  s
# 0   Wed Nov 10 05:28:07 +0000 2021  ...  0
# 1   Wed Nov 10 05:28:07 +0000 2021  ...  2
# 2   Wed Nov 10 05:28:07 +0000 2021  ...  0
# 3   Wed Nov 10 05:28:08 +0000 2021  ...  2
# 4   Wed Nov 10 05:28:08 +0000 2021  ...  0
# 5   Wed Nov 10 05:28:08 +0000 2021  ...  0
# 6   Wed Nov 10 05:28:09 +0000 2021  ...  2
# 7   Wed Nov 10 05:28:08 +0000 2021  ...  0
# 8   Wed Nov 10 05:28:09 +0000 2021  ...  2
# 9   Wed Nov 10 05:28:09 +0000 2021  ...  2
# 10  Wed Nov 10 05:28:09 +0000 2021  ...  2
# 11  Wed Nov 10 05:28:09 +0000 2021  ...  2
# 12  Wed Nov 10 05:28:09 +0000 2021  ...  0
# 13  Wed Nov 10 05:28:09 +0000 2021  ...  0
# 14  Wed Nov 10 05:28:09 +0000 2021  ...  2
# 15  Wed Nov 10 05:28:10 +0000 2021  ...  2
# 16  Wed Nov 10 05:28:10 +0000 2021  ...  2
# 17  Wed Nov 10 05:28:10 +0000 2021  ...  2
# 18  Wed Nov 10 05:28:10 +0000 2021  ...  2
# 19  Wed Nov 10 05:28:10 +0000 2021  ...  2
#
# [20 rows x 3 columns]

# %%
pprint(DF.loc[3])
# Out:
# created_at                       Wed Nov 10 05:28:08 +0000 2021
# text          24-Hour Crypto Market Activity via #LunarCrush...
# s                                                             2
# Name: 3, dtype: object

# %%
pprint(DF.text[4])
# Out:
# ('RT @Amphorium_io: Steve Wozniak finds many benefits of cryptocurrencies\n'
#  'Steve Wozniak believes that there are many advantages of cryptocurr…')
