# %% [markdown]
# ## 패키지

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools

plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['font.family'] = 'Malgun Gothic'

# %% [markdown]
# ## 불러오기

# %%
df = pd.read_csv('c://My_data//17년 세계전기차주제 검색 상대적 추의.csv')

# %%
df1=df.iloc[1:]

# %%
df1.reset_index()
# Out:
#        index 카테고리: 모든 카테고리
# 0    2004-01            30
# 1    2004-02            38
# 2    2004-03            32
# 3    2004-04            34
# 4    2004-05            35
# ..       ...           ...
# 208  2021-05            77
# 209  2021-06            83
# 210  2021-07            95
# 211  2021-08           100
# 212  2021-09            89
#
# [213 rows x 2 columns]

# %%
search_ls=list(((np.array(df1['카테고리: 모든 카테고리'].tolist()))))
search_ls1= list(map(int,search_ls))

# %%
search_ls1[:10]
# Out:
# [30, 38, 32, 34, 35, 35, 29, 30, 28, 33]

# %% [markdown]
# ## 년도를 지정하는 과정
# - n = 일단 월을 지정한다.(순서대로)
# - m = 그다음 매월 1월을 년도의 기준점으로 잡기위해 12로 나누웠을때 나머지가 1인경우만 마크한다
# - l = 그 마크에따라 2004년부터 순서대로 기입한다

# %%
n = []
a = 0
for i in range(len(search_ls)) :
    a = a + 1
    n.append(a)

# %%
m = []
for i in n :
    if i % 12 == 1 :
        m.append(1)
    else:
        m.append(0)

# %%
l = []
a = 2003
for i in m :
    if i == 1 :
        a = a + 1
        l.append(a)
    else :
        l.append('')

# %% [markdown]
# ## 데이터베이스의 값(list = search_ls) 와 지정한 년도 (list =l)
# 을 가지고 그래프를 그려본다.

# %%
plt.figure(figsize=(20,7))
plt.ylim((20,100))
plt.xlim([0,213])
plt.title('2004년~ 현재 세계 전기차주제 검색 변화',size =25)
plt.xlabel('기간(년)', labelpad = 10, size =20, weight = 800, )
plt.ylabel('상대적 검색비율', labelpad = 15 , size =20)
y = np.arange(len(search_ls1))
plt.bar(y, search_ls1,color = '#17becf')
plt.xticks(y, l, fontsize=15)


plt.show()

# %% [markdown]
# ## 이제 평균 이동선을 그려본다

# %%
# 5달 평균
m5 = []
a1=0
a2=0
a3=0
a4=0
a5=0
for i in search_ls1 :
    a1 = a2
    a2 = a3
    a3 = a4
    a4 = a5
    a5 = i
    
    b = (a5+a4+a3+a3+a2+a1)/5
    m5.append(b)

# %%
m5
# Out:
# [6.0,
#  13.6,
#  26.0,
#  34.4,
#  40.2,
#  41.6,
#  40.0,
#  39.6,
#  37.2,
#  37.0,
#  36.2,
#  37.4,
#  36.8,
#  37.0,
#  36.2,
#  38.4,
#  39.6,
#  41.8,
#  41.2,
#  41.0,
#  42.0,
#  41.8,
#  43.2,
#  39.8,
#  38.2,
#  34.6,
#  34.0,
#  35.2,
#  36.2,
#  38.0,
#  39.4,
#  40.4,
#  42.8,
#  42.8,
#  43.0,
#  40.8,
#  38.6,
#  37.8,
#  38.2,
#  38.8,
#  41.2,
#  41.4,
#  43.8,
#  43.0,
#  44.0,
#  42.6,
#  43.0,
#  42.4,
#  42.8,
#  42.8,
#  43.2,
#  45.0,
#  48.0,
#  53.8,
#  57.8,
#  60.0,
#  57.2,
#  52.8,
#  47.4,
#  44.0,
#  42.4,
#  41.4,
#  42.0,
#  41.6,
#  42.0,
#  40.6,
#  40.0,
#  39.8,
#  40.0,
#  41.2,
#  41.2,
#  41.2,
#  40.0,
#  40.0,
#  39.2,
#  40.2,
#  39.4,
#  39.6,
#  38.0,
#  37.0,
#  36.0,
#  36.0,
#  36.4,
#  37.0,
#  37.8,
#  38.0,
#  39.6,
#  40.0,
#  41.2,
#  40.2,
#  38.6,
#  36.6,
#  35.0,
#  34.4,
#  35.0,
#  35.0,
#  36.6,
#  36.6,
#  38.4,
#  38.2,
#  39.0,
#  38.0,
#  37.0,
#  35.4,
#  34.8,
#  34.4,
#  35.0,
#  34.8,
#  35.2,
#  34.6,
#  34.8,
#  35.0,
#  35.0,
#  35.6,
#  35.2,
#  35.2,
#  34.6,
#  33.8,
#  34.4,
#  33.6,
#  34.6,
#  33.6,
#  34.0,
#  34.2,
#  34.6,
#  35.2,
#  35.0,
#  34.8,
#  35.6,
#  35.6,
#  36.6,
#  35.6,
#  35.0,
#  34.0,
#  33.8,
#  34.4,
#  34.8,
#  35.0,
#  34.2,
#  33.6,
#  33.0,
#  33.6,
#  34.4,
#  35.2,
#  35.6,
#  35.6,
#  36.0,
#  37.2,
#  37.8,
#  39.0,
#  37.6,
#  37.6,
#  36.0,
#  36.8,
#  37.6,
#  37.0,
#  35.8,
#  32.0,
#  30.2,
#  28.4,
#  28.6,
#  28.6,
#  29.2,
#  29.8,
#  32.2,
#  33.6,
#  35.8,
#  35.8,
#  36.0,
#  35.8,
#  36.4,
#  37.6,
#  38.8,
#  39.4,
#  39.8,
#  39.2,
#  40.4,
#  41.0,
#  43.0,
#  43.8,
#  45.2,
#  47.8,
#  51.4,
#  54.4,
#  56.6,
#  55.2,
#  56.4,
#  54.8,
#  58.0,
#  58.0,
#  60.6,
#  62.0,
#  65.6,
#  69.2,
#  67.0,
#  62.4,
#  52.4,
#  47.4,
#  46.4,
#  51.6,
#  58.2,
#  61.8,
#  64.4,
#  65.4,
#  70.2,
#  78.2,
#  87.4,
#  96.0,
#  98.2,
#  99.6,
#  99.4,
#  103.8,
#  107.8]

# %%
plt.figure(figsize=(20,7))
plt.ylim((20,100))
plt.xlim([0,213])
plt.title('2004년~ 현재 세계 전기차주제 검색 변화(5개월 이동평균)',size =25)
plt.xlabel('기간(년)', labelpad = 10, size =20, weight = 800, )
plt.ylabel('상대적 검색비율', labelpad = 15 , size =20)
y = np.arange(len(search_ls1))
plt.plot(y, m5, color = '#17becf')
plt.xticks(y, l, fontsize=15)


plt.show()

# %%
# 12달 평균
m12 = []
a1=0
a2=0
a3=0
a4=0
a5=0
a6=0
a7=0
a8=0
a9=0
a10=0
a11=0
a12=0
for i in search_ls1 :
    a1 = a2
    a2 = a3
    a3 = a4
    a4 = a5
    a5 = a6
    a6 = a7
    a7 = a8
    a8 = a9
    a9 = a10
    a10 = a11
    a11 = a12
    a12 = i
    
    b = (a12+a11+a10+a9+a8+a7+a6+a5+a4+a3+a3+a2+a1)/12
    m12.append(b)

# %%
m12
# Out:
# [2.5,
#  5.666666666666667,
#  8.333333333333334,
#  11.166666666666666,
#  14.083333333333334,
#  17.0,
#  19.416666666666668,
#  21.916666666666668,
#  24.25,
#  29.5,
#  32.916666666666664,
#  34.916666666666664,
#  34.833333333333336,
#  34.416666666666664,
#  34.416666666666664,
#  34.333333333333336,
#  34.5,
#  34.0,
#  34.666666666666664,
#  35.166666666666664,
#  36.166666666666664,
#  35.75,
#  36.0,
#  35.75,
#  36.416666666666664,
#  35.916666666666664,
#  35.083333333333336,
#  34.916666666666664,
#  35.083333333333336,
#  35.416666666666664,
#  34.916666666666664,
#  35.083333333333336,
#  34.333333333333336,
#  34.666666666666664,
#  34.583333333333336,
#  34.75,
#  35.833333333333336,
#  35.916666666666664,
#  36.083333333333336,
#  36.583333333333336,
#  37.083333333333336,
#  37.75,
#  37.25,
#  36.583333333333336,
#  36.666666666666664,
#  36.75,
#  37.333333333333336,
#  38.0,
#  38.0,
#  39.083333333333336,
#  38.916666666666664,
#  39.833333333333336,
#  40.666666666666664,
#  42.666666666666664,
#  43.5,
#  44.166666666666664,
#  44.25,
#  44.416666666666664,
#  44.416666666666664,
#  44.166666666666664,
#  44.75,
#  45.166666666666664,
#  45.75,
#  44.25,
#  42.0,
#  39.583333333333336,
#  38.166666666666664,
#  37.5,
#  37.083333333333336,
#  37.166666666666664,
#  37.0,
#  37.166666666666664,
#  36.5,
#  36.5,
#  36.083333333333336,
#  36.166666666666664,
#  36.416666666666664,
#  36.083333333333336,
#  35.916666666666664,
#  35.25,
#  34.666666666666664,
#  34.416666666666664,
#  34.666666666666664,
#  34.083333333333336,
#  34.5,
#  34.083333333333336,
#  34.25,
#  34.333333333333336,
#  34.25,
#  34.25,
#  34.416666666666664,
#  34.25,
#  34.0,
#  34.083333333333336,
#  34.0,
#  34.166666666666664,
#  34.0,
#  33.75,
#  33.333333333333336,
#  32.833333333333336,
#  32.833333333333336,
#  32.916666666666664,
#  32.833333333333336,
#  33.0,
#  32.833333333333336,
#  33.333333333333336,
#  33.083333333333336,
#  33.0,
#  32.583333333333336,
#  32.416666666666664,
#  31.833333333333332,
#  31.5,
#  31.25,
#  31.666666666666668,
#  31.75,
#  31.583333333333332,
#  31.25,
#  31.333333333333332,
#  31.5,
#  31.25,
#  31.25,
#  31.083333333333332,
#  31.25,
#  31.166666666666668,
#  30.916666666666668,
#  30.916666666666668,
#  30.916666666666668,
#  31.333333333333332,
#  31.25,
#  31.666666666666668,
#  31.5,
#  31.5,
#  31.75,
#  31.583333333333332,
#  31.583333333333332,
#  31.666666666666668,
#  31.5,
#  31.916666666666668,
#  31.416666666666668,
#  31.083333333333332,
#  30.666666666666668,
#  30.75,
#  31.0,
#  31.083333333333332,
#  31.333333333333332,
#  31.416666666666668,
#  31.5,
#  31.75,
#  32.0,
#  32.5,
#  32.833333333333336,
#  33.0,
#  33.0,
#  33.333333333333336,
#  33.833333333333336,
#  33.416666666666664,
#  33.083333333333336,
#  32.166666666666664,
#  31.75,
#  30.5,
#  30.0,
#  29.333333333333332,
#  29.5,
#  29.5,
#  28.5,
#  28.166666666666668,
#  28.0,
#  28.583333333333332,
#  29.0,
#  29.583333333333332,
#  30.333333333333332,
#  31.5,
#  32.333333333333336,
#  33.333333333333336,
#  33.75,
#  34.166666666666664,
#  34.5,
#  35.083333333333336,
#  35.916666666666664,
#  36.75,
#  37.666666666666664,
#  39.166666666666664,
#  40.666666666666664,
#  41.583333333333336,
#  42.416666666666664,
#  43.833333333333336,
#  45.5,
#  46.583333333333336,
#  47.583333333333336,
#  49.0,
#  51.25,
#  53.166666666666664,
#  54.083333333333336,
#  55.5,
#  54.0,
#  53.666666666666664,
#  52.25,
#  52.5,
#  52.75,
#  53.5,
#  54.083333333333336,
#  54.583333333333336,
#  55.0,
#  52.75,
#  53.083333333333336,
#  55.916666666666664,
#  60.666666666666664,
#  65.75,
#  69.25,
#  72.5,
#  76.0,
#  80.25,
#  83.33333333333333]

# %%
plt.figure(figsize=(20,7))
plt.ylim((20,100))
plt.xlim([0,213])
plt.title('2004년~ 현재 세계 전기차주제 검색 변화(1년 이동평균)',size =25)
plt.xlabel('기간(년)', labelpad = 10, size =20, weight = 800, )
plt.ylabel('상대적 검색비율', labelpad = 15 , size =20)
y = np.arange(len(search_ls1))
plt.plot(y, m12,color = '#17becf')
plt.xticks(y, l, fontsize=15)


plt.show()

# %% [markdown]
# ## 마지막으로 두 그래프를 합쳐본다

# %%
plt.figure(figsize=(20,7))
plt.ylim((20,100))
plt.xlim([0,213])
plt.title('2004년~ 현재 세계 전기차주제 검색 변화(1년 이동평균)',size =25)
plt.xlabel('기간(년)', labelpad = 10, size =20, weight = 800, )
plt.ylabel('상대적 검색비율', labelpad = 15 , size =20)
y = np.arange(len(search_ls1))
plt.plot(y, m12,color = 'green')
plt.plot(y, m5, color = 'red')
plt.xticks(y, l, fontsize=15)


plt.show()

# %%
plt.figure(figsize=(20,7))
plt.ylim((20,100))
plt.xlim([0,213])
plt.title('2004년~ 현재 세계 전기차주제 검색 변화',size =25)
plt.xlabel('기간(년)', labelpad = 10, size =20, weight = 800, )
plt.ylabel('상대적 검색비율', labelpad = 15 , size =20)

y = np.arange(len(search_ls1))
plt.plot(y, m12,color = 'red', linewidth=2.0 ,label = '12개월 평균이동선', linestyle = '--')

plt.bar(y, search_ls1,color = '#17becf')
plt.xticks(y, l, fontsize=15)
plt.yticks(fontsize = 15)
plt.legend(fontsize =14)


plt.show()
