# %% [markdown]
# ### 아이디어
# - 추세가 일정할때 주기 t가 일정하다
# - 왜냐면 통계. 그리고 중앙회귀는 모든 금융상품에 일어나는 일이여서
# - 추세의 변환을 감정지수로 추론한다.(보안한다)

# %% [markdown]
# ## I. 패키지 밎 자료 불러오기

# %%
# !pip install pymysql
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: pymysql in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (1.4.27)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (4.8.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy) (3.6.0)

# %%
import warnings
warnings.filterwarnings('ignore')
import time
import datetime
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import pymysql
import matplotlib.pyplot as plt
import seaborn as sns

import itertools
import operator

import base64
from io import BytesIO

from datetime import datetime, timedelta


from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# %% [markdown]
# ### 1) 나중에 데이터베이스 커리해서 가져오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls -l '/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_market/Bitcoin.csv'
# Out:
# -rw------- 1 root root 113203 Nov 21 05:53 '/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_market/Bitcoin.csv'

# %%
BTC = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_market/Bitcoin.csv')

# %%
BTC
# Out:
#               Date     Price      Open      High       Low     Vol. Change %
# 0     Nov 21, 2021  58,917.3  59,724.0  59,771.9  58,582.8   42.65K   -1.34%
# 1     Nov 20, 2021  59,717.6  58,080.8  59,854.6  57,435.3   44.53K    2.81%
# 2     Nov 19, 2021  58,083.4  56,908.3  58,335.9  55,626.3   74.44K    1.98%
# 3     Nov 18, 2021  56,955.3  60,368.2  60,936.9  56,524.4  100.37K   -5.65%
# 4     Nov 17, 2021  60,367.8  60,074.2  60,814.5  58,531.9   73.93K    0.46%
# ...            ...       ...       ...       ...       ...      ...      ...
# 1488  Oct 25, 2017   5,734.0   5,513.1   5,748.0   5,375.6  105.84K    4.01%
# 1489  Oct 24, 2017   5,513.1   5,903.6   5,904.6   5,463.4  143.74K   -6.62%
# 1490  Oct 23, 2017   5,903.6   5,982.9   6,049.0   5,644.2  137.14K   -1.32%
# 1491  Oct 22, 2017   5,982.9   6,006.6   6,070.6   5,723.0  105.03K   -0.40%
# 1492  Oct 21, 2017   6,006.6   5,993.1   6,187.2   5,874.5  112.94K    0.23%
#
# [1493 rows x 7 columns]

# %% [markdown]
# ### 2) 변수 정의 밎 전처리

# %%
n = [7,14,30,60,180]
crypto = [BTC]
crypto_name = ['BTC']
bounds = [30,60,180,360,720]

# %%
B = []
for j,k in zip(crypto,crypto_name) :
  for i in range(len(j)):
    x = j['Price'][i]
    date_time_obj = datetime.strptime(j['Date'][i], '%b %d, %Y')
    a = date_time_obj.strftime("%Y-%m-%d")
    b = j['Vol.'][i]
    Y = [a,b,x]
    B.append(Y)
  globals()[k] = pd.DataFrame(B)
  globals()[k].columns = ['date','volume','price']
  # globals()[k] = globals()[k].set_index('date')
  print('완료')
# Out:
# 완료

# %%
DF_price = BTC

# %%
for i in range(len(DF_price['price'])):
  DF_price['price'][i] = DF_price['price'][i].replace(',','')
for i in range(len(DF_price['volume'])):
  DF_price['volume'][i] = DF_price['volume'][i].replace('K','')  
  DF_price['volume'][i] = DF_price['volume'][i].replace('M','')

# %%
DF_price
# Out:
#             date  volume    price
# 0     2021-11-21   42.65  58917.3
# 1     2021-11-20   44.53  59717.6
# 2     2021-11-19   74.44  58083.4
# 3     2021-11-18  100.37  56955.3
# 4     2021-11-17   73.93  60367.8
# ...          ...     ...      ...
# 1488  2017-10-25  105.84   5734.0
# 1489  2017-10-24  143.74   5513.1
# 1490  2017-10-23  137.14   5903.6
# 1491  2017-10-22  105.03   5982.9
# 1492  2017-10-21  112.94   6006.6
#
# [1493 rows x 3 columns]

# %%
for i in range(len(DF_price['price'])):
  DF_price['price'][i] = pd.to_numeric(DF_price['price'][i], downcast = 'float')
  DF_price['volume'][i] = pd.to_numeric(DF_price['volume'][i], downcast = 'float')

# %%
DF_price
# Out:
#             date  volume    price
# 0     2021-11-21   42.65  58917.3
# 1     2021-11-20   44.53  59717.6
# 2     2021-11-19   74.44  58083.4
# 3     2021-11-18  100.37  56955.3
# 4     2021-11-17   73.93  60367.8
# ...          ...     ...      ...
# 1488  2017-10-25  105.84     5734
# 1489  2017-10-24  143.74   5513.1
# 1490  2017-10-23  137.14   5903.6
# 1491  2017-10-22  105.03   5982.9
# 1492  2017-10-21  112.94   6006.6
#
# [1493 rows x 3 columns]

# %%
DF = DF_price

# %% [markdown]
# ## II. 이동평균선 작업

# %%
  for i in n:
    DF_price['MA{0};'.format(i)]= DF_price['price'].rolling(window=i).mean().shift(-(i-1))
    print('완료', 'MA{0};'.format(i))
# Out:
# 완료 MA7;
# 완료 MA14;
# 완료 MA30;
# 완료 MA60;
# 완료 MA180;

# %%
DF = DF_price

# %% [markdown]
# ## III.표준편차,Z밸류,이격도 작업

# %%
for i in n :
  DF_price['MA{0};SD;'.format(i)]=DF_price['price'].rolling(window=i).std().shift(-(i-1))
for i in n :
  DF_price['MA{0};z_value;'.format(i)] = (DF_price['price']-DF_price['MA{0};'.format(i)])/(DF_price['MA{0};SD;'.format(i)])

# %%
DF = DF_price

# %%
DF_price
# Out:
#             date  volume    price  ...  MA30;z_value;  MA60;z_value;  MA180;z_value;
# 0     2021-11-21   42.65  58917.3  ...       -1.21909       0.199605         1.23756
# 1     2021-11-20   44.53  59717.6  ...      -0.946671       0.333799         1.32835
# 2     2021-11-19   74.44  58083.4  ...       -1.66672       0.153712         1.18811
# 3     2021-11-18  100.37  56955.3  ...       -2.26321      0.0411383         1.09362
# 4     2021-11-17   73.93  60367.8  ...       -1.03879       0.479954         1.43332
# ...          ...     ...      ...  ...            ...            ...             ...
# 1488  2017-10-25  105.84     5734  ...            NaN            NaN             NaN
# 1489  2017-10-24  143.74   5513.1  ...            NaN            NaN             NaN
# 1490  2017-10-23  137.14   5903.6  ...            NaN            NaN             NaN
# 1491  2017-10-22  105.03   5982.9  ...            NaN            NaN             NaN
# 1492  2017-10-21  112.94   6006.6  ...            NaN            NaN             NaN
#
# [1493 rows x 18 columns]

# %%
DF_price['disparity7;']= DF_price['price']/DF_price['MA7;']
DF_price['disparity14;']= DF_price['price']/DF_price['MA14;']
DF_price['disparity30;']= DF_price['price']/DF_price['MA30;']
DF_price['disparity60;']= DF_price['price']/DF_price['MA60;']
DF_price['disparity180;']= DF_price['price']/DF_price['MA180;']

# %% [markdown]
# ## IV. 테스트 셋 만들기

# %%
MA7_z_value_data = DF_price[['MA60;z_value;']]

plt.figure(figsize = (12, 5))
plt.plot(MA7_z_value_data)
plt.show()

# %%
test = DF_price['MA60;z_value;'].dropna()

# %%
test = test[::-1].reset_index()

# %%
test =  test[['MA60;z_value;']]

# %%
test
# Out:
#      MA60;z_value;
# 0          1.81086
# 1          1.50042
# 2          1.26196
# 3         0.779723
# 4         0.918208
# ...            ...
# 1429      0.479954
# 1430     0.0411383
# 1431      0.153712
# 1432      0.333799
# 1433      0.199605
#
# [1434 rows x 1 columns]

# %%
scaler = MinMaxScaler(feature_range = (-1, 1))

MA7_z_value_data = scaler.fit_transform(test)

# %%
plt.figure(figsize = (12, 5))
plt.plot(MA7_z_value_data)
plt.show()

# %%
MA7_z_value_data
# Out:
# array([[0.37552393],
#        [0.31259098],
#        [0.26424965],
#        ...,
#        [0.03958495],
#        [0.07609226],
#        [0.04888829]])

# %%
train = MA7_z_value_data[0:1121]
test = MA7_z_value_data[1121:]

# %%
test
# Out:
# array([[ 0.39463019],
#        [ 0.42359478],
#        [ 0.34437934],
#        [ 0.30976754],
#        [ 0.29400141],
#        [ 0.30330715],
#        [ 0.27715625],
#        [ 0.25457127],
#        [ 0.12842367],
#        [ 0.17936448],
#        [ 0.15012558],
#        [ 0.14895222],
#        [ 0.14398041],
#        [ 0.14541525],
#        [ 0.08347949],
#        [ 0.16010148],
#        [ 0.18004817],
#        [ 0.1737647 ],
#        [ 0.13534098],
#        [ 0.14177241],
#        [ 0.19281717],
#        [ 0.2486065 ],
#        [ 0.22234965],
#        [ 0.25410675],
#        [ 0.275541  ],
#        [ 0.25673354],
#        [ 0.46832441],
#        [ 0.45366099],
#        [ 0.39065901],
#        [ 0.46566474],
#        [ 0.43136484],
#        [ 0.41183715],
#        [ 0.43712208],
#        [ 0.40014356],
#        [ 0.4179482 ],
#        [ 0.47540991],
#        [ 0.44094938],
#        [ 0.52761717],
#        [ 0.49925843],
#        [ 0.50898514],
#        [ 0.40918094],
#        [ 0.27209322],
#        [ 0.28296188],
#        [ 0.20716246],
#        [ 0.18650945],
#        [ 0.17551347],
#        [ 0.14470425],
#        [ 0.25478374],
#        [ 0.21690752],
#        [ 0.26130888],
#        [ 0.20178972],
#        [ 0.20507008],
#        [ 0.20027209],
#        [ 0.24953778],
#        [ 0.2757147 ],
#        [ 0.33044361],
#        [ 0.34116677],
#        [ 0.37275853],
#        [ 0.34482233],
#        [ 0.418722  ],
#        [ 0.35361616],
#        [ 0.26712241],
#        [ 0.28207705],
#        [ 0.31580111],
#        [ 0.27774871],
#        [ 0.27753922],
#        [ 0.26843583],
#        [ 0.24477208],
#        [ 0.16822263],
#        [ 0.16937501],
#        [ 0.11541294],
#        [ 0.08647928],
#        [ 0.17121301],
#        [ 0.18686304],
#        [ 0.18075867],
#        [ 0.22543338],
#        [ 0.25214481],
#        [ 0.247781  ],
#        [ 0.24437078],
#        [ 0.25109286],
#        [ 0.18730855],
#        [ 0.22218325],
#        [ 0.24852057],
#        [ 0.21004553],
#        [ 0.1272125 ],
#        [ 0.21396474],
#        [ 0.2094648 ],
#        [ 0.27287807],
#        [ 0.27680996],
#        [ 0.26320695],
#        [ 0.41094083],
#        [ 0.37217544],
#        [ 0.36741874],
#        [ 0.2787564 ],
#        [ 0.21337648],
#        [ 0.04126261],
#        [ 0.01343038],
#        [ 0.05031881],
#        [-0.06675197],
#        [-0.15494956],
#        [-0.17750771],
#        [-0.22614218],
#        [-0.27444008],
#        [-0.05833552],
#        [-0.01978014],
#        [-0.03779939],
#        [-0.11471613],
#        [ 0.0972961 ],
#        [ 0.09656386],
#        [ 0.02475209],
#        [ 0.0502432 ],
#        [-0.16317744],
#        [ 0.05699141],
#        [-0.01611754],
#        [ 0.04058914],
#        [ 0.13747752],
#        [ 0.09418202],
#        [-0.06462504],
#        [-0.0069434 ],
#        [-0.47025168],
#        [-0.42347506],
#        [-0.39448133],
#        [-0.53692261],
#        [-0.51146822],
#        [-0.60109275],
#        [-0.57526504],
#        [-0.73848133],
#        [-0.53082729],
#        [-0.59700696],
#        [-0.54297464],
#        [-0.57684791],
#        [-0.42981291],
#        [-0.41568655],
#        [-0.37198047],
#        [-0.37461833],
#        [-0.42083332],
#        [-0.42225594],
#        [-0.37643309],
#        [-0.32295755],
#        [-0.32276545],
#        [-0.29086316],
#        [-0.24499912],
#        [-0.28569431],
#        [-0.30233439],
#        [-0.28431411],
#        [-0.31840322],
#        [-0.30937404],
#        [-0.21938288],
#        [-0.22575311],
#        [-0.20481369],
#        [-0.23650305],
#        [-0.15578788],
#        [-0.11813592],
#        [-0.12120118],
#        [-0.156766  ],
#        [-0.1574849 ],
#        [-0.20360873],
#        [-0.20222644],
#        [-0.19348105],
#        [-0.27378966],
#        [-0.24602486],
#        [-0.21153795],
#        [-0.18270726],
#        [-0.24379288],
#        [-0.22169534],
#        [-0.16042341],
#        [-0.15929463],
#        [-0.12261292],
#        [-0.13702778],
#        [-0.1685263 ],
#        [-0.15719181],
#        [-0.12781353],
#        [-0.1083553 ],
#        [-0.14954241],
#        [-0.13059314],
#        [-0.14082964],
#        [-0.17759243],
#        [-0.14364091],
#        [-0.16244021],
#        [-0.12593778],
#        [-0.185296  ],
#        [-0.21594661],
#        [-0.21431437],
#        [-0.29300735],
#        [-0.3285421 ],
#        [-0.32027692],
#        [-0.2862411 ],
#        [-0.35590656],
#        [-0.4182743 ],
#        [-0.22129254],
#        [-0.20262165],
#        [-0.09339161],
#        [-0.07048942],
#        [ 0.0658131 ],
#        [ 0.23007699],
#        [ 0.39901957],
#        [ 0.42175236],
#        [ 0.40263705],
#        [ 0.5372146 ],
#        [ 0.46385856],
#        [ 0.33756339],
#        [ 0.28847676],
#        [ 0.21389509],
#        [ 0.31355659],
#        [ 0.37362295],
#        [ 0.46931102],
#        [ 0.53928256],
#        [ 0.46408446],
#        [ 0.55793978],
#        [ 0.48945709],
#        [ 0.45906426],
#        [ 0.38825148],
#        [ 0.51673707],
#        [ 0.46105581],
#        [ 0.43434801],
#        [ 0.37703154],
#        [ 0.31268179],
#        [ 0.30261991],
#        [ 0.36446235],
#        [ 0.43685215],
#        [ 0.40020787],
#        [ 0.39372991],
#        [ 0.38451936],
#        [ 0.31135729],
#        [ 0.34014711],
#        [ 0.25983943],
#        [ 0.31981488],
#        [ 0.3027622 ],
#        [ 0.28826142],
#        [ 0.22509892],
#        [ 0.2221117 ],
#        [ 0.26538746],
#        [ 0.26985787],
#        [ 0.28205033],
#        [ 0.27017733],
#        [ 0.3142576 ],
#        [ 0.32901631],
#        [ 0.14839871],
#        [ 0.12187102],
#        [ 0.12672231],
#        [ 0.07455546],
#        [ 0.07942756],
#        [ 0.10292785],
#        [ 0.06122669],
#        [ 0.12722722],
#        [ 0.15886887],
#        [ 0.14057134],
#        [ 0.11875413],
#        [ 0.15637932],
#        [ 0.1071181 ],
#        [-0.10100227],
#        [-0.22425848],
#        [-0.0943588 ],
#        [-0.03468911],
#        [-0.16522635],
#        [-0.18075158],
#        [-0.15575412],
#        [-0.22668925],
#        [-0.29631457],
#        [-0.26369245],
#        [-0.1267064 ],
#        [ 0.14988452],
#        [ 0.11305213],
#        [ 0.14711149],
#        [ 0.21940192],
#        [ 0.37665054],
#        [ 0.60861942],
#        [ 0.47071698],
#        [ 0.45170149],
#        [ 0.48503501],
#        [ 0.44258797],
#        [ 0.56095629],
#        [ 0.45177652],
#        [ 0.49064961],
#        [ 0.45970963],
#        [ 0.60866688],
#        [ 0.53044147],
#        [ 0.51960155],
#        [ 0.5038932 ],
#        [ 0.54429953],
#        [ 0.55711925],
#        [ 0.40856168],
#        [ 0.34472227],
#        [ 0.34912091],
#        [ 0.32253414],
#        [ 0.3717431 ],
#        [ 0.28032169],
#        [ 0.21917863],
#        [ 0.27190112],
#        [ 0.3072791 ],
#        [ 0.28544085],
#        [ 0.2618493 ],
#        [ 0.24325468],
#        [ 0.29498543],
#        [ 0.27722057],
#        [ 0.23108766],
#        [ 0.21423399],
#        [ 0.22018727],
#        [ 0.25727123],
#        [ 0.35060091],
#        [ 0.32251752],
#        [ 0.2646054 ],
#        [ 0.25295253],
#        [ 0.22903815],
#        [ 0.22805915],
#        [ 0.24705897],
#        [ 0.19387591],
#        [ 0.10319496],
#        [ 0.10572074],
#        [ 0.01676385],
#        [ 0.03958495],
#        [ 0.07609226],
#        [ 0.04888829]])

# %% [markdown]
# ### 1) 학습생성 데이터 생성 함수 정의

# %%
# # time_priod 몃일간 데이터를 줄것인가?
# def create_dataset(time_data, time_priod , prediction):
#   data_X, data_y = [], []

#   for i in range(len(time_date) - time_priod):
#     date_X.append(time_data[i+1:(i+1 + time_priod), 0])
#     date_y.append(time_data[i+1 - prediction, 0])

#   return np.array(data_X), np.array(data_y)

# %%
def create_dataset(time_data, look_back = 1):
    data_X, data_y = [], []

    for i in range(len(time_data) - look_back):
        data_X.append(time_data[i:(i + look_back), 0])
        data_y.append(time_data[i + look_back, 0])

    return np.array(data_X), np.array(data_y)

# %%
look_back = 120

train_X, train_y = create_dataset(train, look_back)
test_X,  test_y  = create_dataset(test, look_back)

# %%
# time_priod = 7
# prediction = 1

# train_X, train_y = create_dataset(train, time_priod, prediction)
# test_X,  test_y  = create_dataset(test, time_priod, prediction)

# train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-8bd0c9fc0316> in <module>()
#       2 prediction = 1
#       3
# ----> 4 train_X, train_y = create_dataset(train, time_priod, prediction)
#       5 test_X,  test_y  = create_dataset(test, time_priod, prediction)
#       6
#
# <ipython-input-48-f01b5b32ee6c> in create_dataset(time_data, time_priod, prediction)
#       3   data_X, data_y = [], []
#       4
# ----> 5   for i in range(len(time_date) - time_priod):
#       6     date_X.append(time_data[i+1:(i+1 + time_priod), 0])
#       7     date_y.append(time_data[i+1 - prediction, 0])
#
# NameError: name 'time_date' is not defined

# %%
train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1))
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))

train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((1001, 120, 1), (1001,), (193, 120, 1), (193,))

# %% [markdown]
# ## V.LSTM 모델

# %%
model = Sequential(name = 'LSTM')
model.add(LSTM(128, 
               input_shape = (None, 1)))
model.add(Dense(1, activation = 'tanh'))

# %%
model.summary()
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               66560
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'mean_squared_error', 
              optimizer = 'adam')

# %%
# %%time

hist = model.fit(train_X, train_y,
                 epochs = 200, 
                 batch_size = 32,  
                 validation_data = (test_X, test_y))
# Out:
# Epoch 1/200
# 32/32 [==============================] - 3s 49ms/step - loss: 0.0219 - val_loss: 0.0172
# Epoch 2/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0132 - val_loss: 0.0126
# Epoch 3/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0110 - val_loss: 0.0110
# Epoch 4/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0098 - val_loss: 0.0089
# Epoch 5/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0090 - val_loss: 0.0083
# Epoch 6/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0086 - val_loss: 0.0075
# Epoch 7/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0081 - val_loss: 0.0074
# Epoch 8/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0078 - val_loss: 0.0071
# Epoch 9/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0076 - val_loss: 0.0066
# Epoch 10/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0072 - val_loss: 0.0067
# Epoch 11/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0072 - val_loss: 0.0066
# Epoch 12/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0068 - val_loss: 0.0063
# Epoch 13/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0067 - val_loss: 0.0067
# Epoch 14/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0067 - val_loss: 0.0058
# Epoch 15/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 16/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0063 - val_loss: 0.0053
# Epoch 17/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 18/200
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 19/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 20/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0061 - val_loss: 0.0055
# Epoch 21/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0062 - val_loss: 0.0051
# Epoch 22/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0059 - val_loss: 0.0050
# Epoch 23/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 24/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 25/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 26/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 27/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 28/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 29/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 30/200
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 31/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 32/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 33/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 34/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 35/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 36/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 37/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 38/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 39/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 40/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0059 - val_loss: 0.0048
# Epoch 41/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 42/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 43/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 44/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 45/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 46/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 47/200
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 48/200
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 49/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 50/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 51/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0059 - val_loss: 0.0050
# Epoch 52/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0059 - val_loss: 0.0048
# Epoch 53/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 54/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 55/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 56/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 57/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 58/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 59/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 60/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 61/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 62/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 63/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 64/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 65/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 66/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0059 - val_loss: 0.0050
# Epoch 67/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 68/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 69/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 70/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 71/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 72/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 73/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 74/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 75/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 76/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 77/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 78/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 79/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 80/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 81/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0059 - val_loss: 0.0050
# Epoch 82/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 83/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 84/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 85/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 86/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 87/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 88/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 89/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 90/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 91/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0059 - val_loss: 0.0048
# Epoch 92/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 93/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0057 - val_loss: 0.0050
# Epoch 94/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 95/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0060 - val_loss: 0.0048
# Epoch 96/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 97/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 98/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 99/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 100/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 101/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 102/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0059 - val_loss: 0.0048
# Epoch 103/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 104/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0059 - val_loss: 0.0050
# Epoch 105/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0059 - val_loss: 0.0048
# Epoch 106/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 107/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 108/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 109/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 110/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 111/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 112/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 113/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 114/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 115/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 116/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 117/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 118/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 119/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 120/200
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 121/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 122/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 123/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 124/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 125/200
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 126/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 127/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 128/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 129/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0047
# Epoch 130/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 131/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 132/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 133/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 134/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 135/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 136/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 137/200
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 138/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 139/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0057 - val_loss: 0.0050
# Epoch 140/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 141/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 142/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0057 - val_loss: 0.0050
# Epoch 143/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 144/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 145/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 146/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 147/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 148/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 149/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 150/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 151/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0051
# Epoch 152/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 153/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0050
# Epoch 154/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 155/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 156/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 157/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 158/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 159/200
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0056 - val_loss: 0.0049
# Epoch 160/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0056 - val_loss: 0.0049
# Epoch 161/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 162/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 163/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 164/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 165/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 166/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 167/200
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 168/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 169/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0056 - val_loss: 0.0054
# Epoch 170/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0051
# Epoch 171/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 172/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 173/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 174/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 175/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 176/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0057 - val_loss: 0.0050
# Epoch 177/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 178/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 179/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 180/200
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 181/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 182/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 183/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 184/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 185/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0055 - val_loss: 0.0057
# Epoch 186/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 187/200
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0054 - val_loss: 0.0058
# Epoch 188/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0054 - val_loss: 0.0057
# Epoch 189/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0054 - val_loss: 0.0057
# Epoch 190/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0054 - val_loss: 0.0064
# Epoch 191/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0053 - val_loss: 0.0061
# Epoch 192/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0053 - val_loss: 0.0061
# Epoch 193/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 194/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0055 - val_loss: 0.0057
# Epoch 195/200
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0053 - val_loss: 0.0061
# Epoch 196/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0054 - val_loss: 0.0061
# Epoch 197/200
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 198/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0052 - val_loss: 0.0061
# Epoch 199/200
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0052 - val_loss: 0.0059
# Epoch 200/200
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0053 - val_loss: 0.0066
# CPU times: user 2min 49s, sys: 9.04 s, total: 2min 58s
# Wall time: 3min 29s

# %%
#epoch = 200 batch size = 16
plt.figure(figsize = (12, 5))
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])

plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train Loss', 'Valid Loss'], loc = 'upper right')
plt.show()

# %%
#epoch = 200 batch size = 32
plt.figure(figsize = (12, 5))
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])

plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train Loss', 'Valid Loss'], loc = 'upper right')
plt.show()

# %%
trainScore = model.evaluate(train_X, train_y, verbose = 0)
print('Train Score: ', trainScore)

testScore = model.evaluate(test_X, test_y, verbose = 0)
print('Test Score: ', testScore)
# Out:
# Train Score:  0.005058864131569862
# Test Score:  0.006647360976785421

# %%
look_ahead = 193

xhat = test_X[0]

predictions = np.zeros((look_ahead, 1))

for i in range(look_ahead):
    prediction = model.predict(np.array([xhat]), batch_size = 1)
    predictions[i] = prediction
    xhat = np.vstack([xhat[1:], prediction])
    
plt.figure(figsize = (12, 5))
plt.plot(np.arange(look_ahead), predictions, 'r', label = 'Prediction')
plt.plot(np.arange(look_ahead), test_y[:look_ahead], label = 'Test_Data')


# plt.axhline(y=2.5, color='b', linewidth=1)
# plt.axhline(y=-2.5, color='b', linewidth=1)

plt.axhline(y=0, color='g', linewidth=1)

plt.legend()
plt.show()

# %%
predictions
# Out:
# array([[ 0.2423213 ],
#        [ 0.31881759],
#        [ 0.32786557],
#        [ 0.37016237],
#        [ 0.39410993],
#        [ 0.39632383],
#        [ 0.40981111],
#        [ 0.33461869],
#        [ 0.25254205],
#        [ 0.33432212],
#        [ 0.39763302],
#        [ 0.35995686],
#        [ 0.37305108],
#        [ 0.37222689],
#        [ 0.12790118],
#        [-0.03726723],
#        [-0.14267677],
#        [-0.27145243],
#        [-0.41583684],
#        [-0.51162809],
#        [-0.3617135 ],
#        [-0.39315045],
#        [-0.43452716],
#        [-0.38813567],
#        [-0.29262856],
#        [-0.26309681],
#        [-0.22939701],
#        [-0.28878161],
#        [-0.31497511],
#        [-0.28896075],
#        [-0.1229022 ],
#        [ 0.02029919],
#        [ 0.2861169 ],
#        [ 0.28773478],
#        [-0.03711022],
#        [-0.54927409],
#        [-0.62808007],
#        [-0.60042119],
#        [-0.70308727],
#        [-0.3713901 ],
#        [-0.56733799],
#        [-0.46976784],
#        [-0.09625462],
#        [-0.51150215],
#        [-0.43631661],
#        [-0.20855241],
#        [-0.42795867],
#        [-0.10778091],
#        [ 0.12652643],
#        [ 0.09950764],
#        [-0.07151122],
#        [-0.37674788],
#        [-0.01630059],
#        [ 0.33295748],
#        [ 0.60512799],
#        [ 0.51125348],
#        [ 0.34670246],
#        [ 0.32622704],
#        [-0.12500787],
#        [-0.27079076],
#        [-0.10545781],
#        [-0.19456407],
#        [-0.22170901],
#        [-0.19695739],
#        [-0.22323455],
#        [-0.33539802],
#        [-0.54388207],
#        [-0.46858039],
#        [-0.05225279],
#        [-0.25699028],
#        [-0.43692356],
#        [-0.24443172],
#        [-0.2256847 ],
#        [-0.32915142],
#        [-0.27981105],
#        [-0.16892253],
#        [-0.02373467],
#        [ 0.20660825],
#        [ 0.11940552],
#        [-0.3333801 ],
#        [-0.574817  ],
#        [-0.51148677],
#        [-0.59717989],
#        [-0.63974124],
#        [-0.64066786],
#        [-0.6049096 ],
#        [-0.50987864],
#        [-0.47040156],
#        [-0.35069066],
#        [-0.31435767],
#        [-0.27373558],
#        [-0.20329425],
#        [-0.18384483],
#        [-0.03166161],
#        [ 0.09787165],
#        [-0.01823361],
#        [ 0.28365436],
#        [ 0.24215434],
#        [ 0.80813169],
#        [ 0.23730934],
#        [ 0.27014187],
#        [ 0.04965065],
#        [ 0.1734979 ],
#        [ 0.05771311],
#        [ 0.08939065],
#        [ 0.12258137],
#        [ 0.14880286],
#        [ 0.1373602 ],
#        [ 0.13547307],
#        [ 0.2230482 ],
#        [ 0.38883883],
#        [ 0.50164735],
#        [ 0.45256284],
#        [ 0.36373019],
#        [ 0.26901162],
#        [ 0.22220547],
#        [ 0.2158787 ],
#        [ 0.22668652],
#        [ 0.17027995],
#        [ 0.12061806],
#        [ 0.45662314],
#        [ 0.66704607],
#        [ 0.74919361],
#        [ 0.69248605],
#        [ 0.5654065 ],
#        [ 0.41408381],
#        [ 0.32123578],
#        [ 0.38193306],
#        [ 0.264301  ],
#        [ 0.42079052],
#        [ 0.52081978],
#        [ 0.65187913],
#        [ 0.56106365],
#        [ 0.46389014],
#        [ 0.53320402],
#        [ 0.54896057],
#        [ 0.54976285],
#        [ 0.44913077],
#        [ 0.34010816],
#        [ 0.30527335],
#        [ 0.34258148],
#        [ 0.38027927],
#        [ 0.29365945],
#        [ 0.13172969],
#        [-0.02460724],
#        [-0.29226676],
#        [-0.3450067 ],
#        [-0.46224773],
#        [-0.59652227],
#        [-0.25587696],
#        [-0.4755429 ],
#        [-0.43290046],
#        [-0.43506181],
#        [-0.34529439],
#        [-0.32749057],
#        [-0.32585806],
#        [-0.29961091],
#        [-0.24333777],
#        [-0.23972166],
#        [-0.14379264],
#        [-0.08202734],
#        [ 0.18261059],
#        [ 0.06567657],
#        [ 0.21563014],
#        [-0.31899545],
#        [-0.06873801],
#        [-0.23188214],
#        [-0.2899459 ],
#        [-0.05324429],
#        [-0.3721644 ],
#        [-0.39629939],
#        [-0.390255  ],
#        [-0.56432569],
#        [-0.28483149],
#        [-0.06800528],
#        [-0.18443252],
#        [ 0.2805582 ],
#        [ 0.36619565],
#        [ 0.37530261],
#        [ 0.09264308],
#        [-0.01755669],
#        [ 0.08005016],
#        [ 0.17389598],
#        [ 0.21615784],
#        [ 0.32350406],
#        [ 0.20917934],
#        [-0.17438121],
#        [-0.2713885 ],
#        [-0.4883562 ],
#        [-0.30770627],
#        [-0.05999289],
#        [-0.07438409],
#        [-0.22588538],
#        [-0.10472849],
#        [ 0.10884792],
#        [ 0.27456516],
#        [-0.26000118],
#        [-0.33576006],
#        [-0.2131944 ],
#        [ 0.29008016],
#        [ 0.44399458],
#        [ 0.55816716],
#        [ 0.54284209],
#        [ 0.35853595],
#        [ 0.55102062],
#        [ 0.48756617],
#        [ 0.51530486],
#        [ 0.55178577],
#        [ 0.47832   ],
#        [ 0.45450431],
#        [ 0.41329363],
#        [ 0.31405008],
#        [ 0.40306506],
#        [ 0.56652135],
#        [ 0.25423282],
#        [ 0.20886658],
#        [ 0.20921305],
#        [ 0.35992622],
#        [ 0.64152873],
#        [ 0.73010105],
#        [ 0.43482682],
#        [ 0.13255222],
#        [ 0.39533642],
#        [ 0.3770718 ],
#        [ 0.28425285],
#        [ 0.33524859],
#        [-0.0106281 ],
#        [-0.10199156],
#        [-0.21638767],
#        [-0.20601135],
#        [-0.39942366],
#        [-0.52432919],
#        [-0.25469476],
#        [-0.46584776],
#        [-0.40209082],
#        [-0.49613115],
#        [-0.40499252],
#        [-0.37534428],
#        [-0.30647478],
#        [-0.2963711 ],
#        [-0.37973052],
#        [-0.25583375],
#        [-0.15583836],
#        [-0.09016426],
#        [ 0.11374072],
#        [ 0.00857464],
#        [-0.00958451],
#        [-0.58553118],
#        [-0.21813379],
#        [-0.53208679],
#        [-0.39335108],
#        [-0.38738614],
#        [-0.59990746],
#        [-0.61858773],
#        [-0.37277353],
#        [-0.41262621],
#        [-0.24418974],
#        [-0.11149322],
#        [-0.26633328],
#        [-0.03211972],
#        [ 0.18425968],
#        [ 0.03040979],
#        [ 0.23455359],
#        [ 0.18685393],
#        [ 0.45503506],
#        [ 0.64741641],
#        [ 0.18545984],
#        [ 0.27738106],
#        [ 0.04674213],
#        [ 0.06667005],
#        [ 0.06727821],
#        [ 0.07470489],
#        [ 0.02174313],
#        [ 0.1286052 ],
#        [ 0.23415665],
#        [ 0.23125434],
#        [ 0.51582348],
#        [ 0.56827587],
#        [ 0.51506257],
#        [ 0.58785355],
#        [ 0.54863697],
#        [ 0.49311826],
#        [ 0.51882017],
#        [ 0.59833711],
#        [ 0.65393925],
#        [ 0.61308044],
#        [ 0.62508523],
#        [ 0.7057004 ],
#        [ 0.6934582 ],
#        [ 0.54034466],
#        [ 0.3240383 ],
#        [ 0.38039023],
#        [ 0.36689416],
#        [ 0.36126935],
#        [ 0.26133549],
#        [ 0.14035641],
#        [ 0.04688931],
#        [ 0.04588551],
#        [ 0.12290604],
#        [ 0.27654049],
#        [ 0.5005179 ],
#        [ 0.53352678],
#        [ 0.45131153],
#        [ 0.39521748],
#        [ 0.14094414],
#        [ 0.09853748],
#        [ 0.1219243 ],
#        [ 0.11195461],
#        [-0.15011629],
#        [-0.47044173],
#        [-0.47176594],
#        [-0.2784636 ],
#        [-0.24708234],
#        [-0.15422758],
#        [-0.09575611],
#        [-0.15478021],
#        [-0.18517937],
#        [-0.15556325],
#        [ 0.10862692],
#        [ 0.1823345 ],
#        [-0.10744438],
#        [-0.2756097 ],
#        [-0.55602074],
#        [-0.59867787],
#        [-0.40046045],
#        [-0.30548102],
#        [-0.1509084 ],
#        [ 0.16798922],
#        [ 0.29976904],
#        [ 0.1844146 ],
#        [ 0.14503132]])

# %% [markdown]
# ## IV. EDA z_value

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['MA7;z_value;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')

plt.axhline(y=0, color='g', linewidth=1)
plt.axhline(y=1.6, color='b', linewidth=1)
plt.axhline(y=-1.6, color='b', linewidth=1)

plt.show()

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['MA14;z_value;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')

plt.axhline(y=0, color='g', linewidth=1)
plt.axhline(y=2, color='b', linewidth=1)
plt.axhline(y=-2, color='b', linewidth=1)

plt.show()

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['MA30;z_value;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')
plt.axhline(y=2.5, color='b', linewidth=1)
plt.axhline(y=-2.5, color='b', linewidth=1)

plt.axhline(y=0, color='g', linewidth=1)

plt.show()

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['MA60;z_value;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')

plt.axhline(y=0, color='g', linewidth=1)
plt.axhline(y=2.2, color='b', linewidth=1)
plt.axhline(y=-2.2, color='b', linewidth=1)

plt.show()

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['MA180;z_value;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')

plt.axhline(y=0, color='g', linewidth=1)

plt.show()

# %% [markdown]
# ## V. z_value 평균이동선 작업밎 EDA

# %%
  for i in n:
    DF_price['MA{0};z_value;MA{0};'.format(i)]= DF_price['MA{0};z_value;'.format(i)].rolling(window=i).mean().shift(-(i-1))
    print('완료', 'MA{0};''MA{0};z_value;MA{0};'.format(i))
# Out:
# 완료 MA7;MA7;z_value;MA7;
# 완료 MA14;MA14;z_value;MA14;
# 완료 MA30;MA30;z_value;MA30;
# 완료 MA60;MA60;z_value;MA60;
# 완료 MA180;MA180;z_value;MA180;

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['MA7;z_value;MA7;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')

plt.axhline(y=0, color='g', linewidth=1)

plt.show()

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['MA14;z_value;MA14;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')

plt.axhline(y=0, color='g', linewidth=1)

plt.show()

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['MA30;z_value;MA30;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')

plt.axhline(y=0, color='g', linewidth=1)

plt.show()

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['MA60;z_value;MA60;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')

plt.axhline(y=0, color='g', linewidth=1)

plt.show()

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['MA180;z_value;MA180;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')

plt.axhline(y=0, color='g', linewidth=1)

plt.show()

# %% [markdown]
# ## VI. 이격도(disparity) 작업 밎 EDA

# %%
DF_price['disparity7;']= DF_price['price']/DF_price['MA7;']
DF_price['disparity14;']= DF_price['price']/DF_price['MA14;']
DF_price['disparity30;']= DF_price['price']/DF_price['MA30;']
DF_price['disparity60;']= DF_price['price']/DF_price['MA60;']
DF_price['disparity180;']= DF_price['price']/DF_price['MA180;']

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['disparity7;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')

plt.axhline(y=1, color='g', linewidth=1)
plt.axhline(y=1.1, color='b', linewidth=1)
plt.axhline(y=0.90, color='b', linewidth=1)

plt.show()

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['disparity14;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')
plt.axhline(y=1.1, color='b', linewidth=1)
plt.axhline(y=0.90, color='b', linewidth=1)

plt.axhline(y=1, color='g', linewidth=1)

plt.show()

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['disparity30;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')
# plt.axhline(y=1.25, color='b', linewidth=1)
# plt.axhline(y=0.75, color='b', linewidth=1)

plt.axhline(y=1, color='g', linewidth=1)

plt.show()

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['disparity60;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')

plt.axhline(y=1, color='g', linewidth=1)

plt.show()

# %%
x_values = DF_price['date']	
# y_values = DF_price['s']
z_values = DF_price['disparity180;']

plt.rcParams['figure.figsize'] = (20, 10)

fig, ax2 = plt.subplots()

ax2.invert_xaxis()
ax2.plot(x_values, z_values , color = 'deeppink')

plt.axhline(y=1, color='g', linewidth=1)

plt.show()
